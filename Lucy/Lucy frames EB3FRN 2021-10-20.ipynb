# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from construct import *
import scipy.signal

import sys
sys.path.append('../Tianwen/') # to import ccsds
import ccsds

import struct
import collections
import pathlib

# %%
AOSFrame = Struct(
    'primary_header' / ccsds.AOSPrimaryHeader,
    'm_pdu_header' / ccsds.M_PDU_Header,
    'm_pdu_packet_zone' / GreedyBytes
)

def packets_asarray(packets):
    packets = [np.frombuffer(p[ccsds.SpacePacketPrimaryHeader.sizeof():], 'uint8')
               for p in packets]
    l = np.max([p.size for p in packets])
    packets = [np.concatenate((p, np.zeros(l-p.size, 'uint8'))) for p in packets]
    return np.array(packets)

def plot_apids(apids, vc=0):
    for apid in sorted(apids.keys()):
        plt.figure(figsize = (16,16), facecolor = 'w')
        ps = packets_asarray(apids[apid])
        plt.imshow(ps, aspect = ps.shape[1]/ps.shape[0], interpolation='none')
        plt.title(f"Lucy APID {apid} Virtual channel {vc}")

# %% [markdown]
# Timestamps are contained in the Space Packet secondary header time code field. They are encoded as big-endian 32-bit integers counting the number of seconds elapsed since the J2000 epoch (2000-01-01T12:00:00).
#
# Looking at the idle APID packets, the next byte might indicate fractional seconds (since it is still part of the secondary header rather than idle data), but it is difficult to be sure.

# %%
def timestamps(packets):
    epoch = np.datetime64('2000-01-01T12:00:00')
    t = np.array([struct.unpack('>I', p[ccsds.SpacePacketPrimaryHeader.sizeof():][:4])[0]
                  for p in packets], 'uint32')
    return epoch + t * np.timedelta64(1, 's')

# %%
def load_frames(path):
    frame_size = 223 * 5 - 2
    frames = np.fromfile(path, dtype = 'uint8')
    frames = frames[:frames.size//frame_size*frame_size].reshape((-1, frame_size))
    return frames

# %%
frames = np.concatenate((
    load_frames('lucy_frames_eb3frn_20211020_233618.u8'),
    load_frames('lucy_frames_eb3frn_20211020_235911.u8')))
frames.shape[0]
# Out:
# 178

# %% [markdown]
# ## AOS frames
#
# Telemetry is in Virtual Channel 1. Virtual channel 63 contains Only Idle Data.

# %%
aos = [AOSFrame.parse(f) for f in frames]

# %%
collections.Counter([a.primary_header.transfer_frame_version_number for a in aos])
# Out:
# Counter({1: 178})

# %%
collections.Counter([a.primary_header.spacecraft_id for a in aos])
# Out:
# Counter({49: 178})

# %%
collections.Counter([a.primary_header.virtual_channel_id for a in aos])
# Out:
# Counter({63: 156, 0: 22})

# %% [markdown]
# ## Virtual Channel 63 (Only Idle Data)
#
# Virtual channel 63 corresponds to Only Idle Data. The transfer frame data field includes an M_PDU header with a first header pointer equal to `0x7fe`, which indicates that the packet zone contains only idle data. The packet zone is filled with `0xaa`'s.

# %%
vc63 = [a for a in aos if a.primary_header.virtual_channel_id == 63]
[a.primary_header for a in vc63[:10]]
# Out:
# [Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388691, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388699, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388707, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388717, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388722, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388733, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388766, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388767, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388776, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=63, virtual_channel_frame_count=388786, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0)]

# %%
vc63_frames = np.array([f for f, a in zip(frames, aos) if a.primary_header.virtual_channel_id == 63])

# %%
np.unique(vc63_frames[:, 6:8], axis = 0)
# Out:
# array([[  7, 254]], dtype=uint8)

# %%
bytes(vc63_frames[0, 6:8]).hex()
# Out:
# '07fe'

# %%
np.unique(vc63_frames[:, 8:])
# Out:
# array([170], dtype=uint8)

# %%
hex(170)
# Out:
# '0xaa'

# %%
fc = np.array([a.primary_header.virtual_channel_frame_count for a in vc63])

# %%
plt.figure(figsize = (10, 5), facecolor = 'w')
plt.plot(fc[1:], np.diff(fc)-1, '.')
plt.title("Lucy virtual channel 63 (OID) frame loss")
plt.xlabel('Virtual channel frame counter')
plt.ylabel('Lost frames');

# %%
last_part = fc > 391000
fc[last_part].size/(fc[-1]-fc[last_part][0]+1)
# Out:
# 0.08978529603122967

# %% [markdown]
# ## Virtual channel 0
#
# Virtual channel 0 contains telemetry. There are a few active APIDs sending CCSDS Space Packets using the AOS M_PDU protocol.

# %%
vc0 = [a for a in aos if a.primary_header.virtual_channel_id == 0]
[a.primary_header for a in vc0[:10]]
# Out:
# [Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1018971, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1018982, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019325, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019336, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019339, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019345, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019362, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019398, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019401, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0),
#  Container(transfer_frame_version_number=1, spacecraft_id=49, virtual_channel_id=0, virtual_channel_frame_count=1019403, replay_flag=False, vc_frame_count_usage_flag=False, rsvd_spare=0, vc_framecount_cycle=0)]

# %%
fc = np.array([a.primary_header.virtual_channel_frame_count for a in vc0])

# %%
plt.figure(figsize = (10, 5), facecolor = 'w')
plt.plot(fc[1:], np.diff(fc)-1, '.')
plt.title("Lucy virtual channel 0 (telemetry) frame loss")
plt.xlabel('Virtual channel frame counter')
plt.ylabel('Lost frames');

# %%
last_part = fc > 391000
fc[last_part].size/(fc[-1]-fc[last_part][0]+1)
# Out:
# 0.03935599284436494

# %%
vc0_packets = list(ccsds.extract_space_packets(vc0, 49, 0))
# Out:
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1018971, current frame count 1018982
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1018982, current frame count 1019325
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019325, current frame count 1019336
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019336, current frame count 1019339
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019339, current frame count 1019345
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019345, current frame count 1019362
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019362, current frame count 1019398
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019398, current frame count 1019401
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019401, current frame count 1019403
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019403, current frame count 1019416
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019417, current frame count 1019434
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019434, current frame count 1019438
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019438, current frame count 1019443
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019443, current frame count 1019446
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019446, current frame count 1019459
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019459, current frame count 1019469
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019469, current frame count 1019505
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019505, current frame count 1019520
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')
# /home/daniel/jupyter_notebooks/Lucy/../Tianwen/ccsds.py:79: UserWarning: [Space Packet extractor Spacecraft 49 VC 0] Broken stream. Last frame count 1019520, current frame count 1019528
#   warnings.warn(f'[Space Packet extractor Spacecraft {sc_id} VC {virtual_channel}] Broken stream. Last frame count {frame_count}, current frame count {frame_count_new}')

# %%
vc0_t = timestamps(vc0_packets)

# %%
vc0_sp_headers = [ccsds.SpacePacketPrimaryHeader.parse(p) for p in vc0_packets]

# %%
vc0_apids = collections.Counter([p.APID for p in vc0_sp_headers])
vc0_apids
# Out:
# Counter({7: 9, 1032: 9, 2047: 14, 5: 5, 1030: 7})

# %%
apid_axis = {a : k for k, a in enumerate(sorted(vc0_apids))}

# %%
plt.figure(figsize = (10, 5), facecolor = 'w')
plt.plot(vc0_t, [apid_axis[p.APID] for p in vc0_sp_headers], '.')
plt.yticks(ticks=range(len(apid_axis)), labels=apid_axis)
plt.xlabel('Space Packet timestamp')
plt.ylabel('APID')
plt.title('Lucy Virtual Channel 0 APID distribution');

# %%
vc0_by_apid = {apid : [p for h,p in zip(vc0_sp_headers, vc0_packets)
                       if h.APID == apid] for apid in vc0_apids}

# %%
plot_apids(vc0_by_apid)

# %% [markdown]
# ### APID 5
#
# As [found by r00t](https://twitter.com/r2x0t/status/1449760174009462784) this APID has frames of fixed size containing a number of fields in tag-value format. Tags are 2 bytes, and values have different formats and sizes depending on the tag.

# %%
tags = {2: Int16ub, 3: Int16ub, 15: Int32ub, 31: Int16ub, 32: Int16ub, 1202: Float64b,
        1203: Float64b, 1204: Float64b, 1205: Float64b, 1206: Float64b, 1208: Float32b,
        1209: Float32b, 1210: Float32b, 1601: Float32b, 1602: Float32b, 1603: Float32b,
        1630: Float32b, 1631: Float32b, 1632: Float32b, 17539: Float32b, 17547: Float32b,
        17548: Float32b, 21314: Int32sb, 21315: Int32sb, 21316: Int32sb, 21317: Int32sb,
        46555: Int32sb, 46980: Int16ub, 46981: Int16ub, 46982: Int16ub, 47090: Int16ub,
        47091: Int16ub, 47092: Int16ub,
       }

# %%
values = list()
for packet in vc0_by_apid[5]:
    t = timestamps([packet])[0]
    packet = packet[6+5:]  # skip primary and secondary headers
    while True:
        tag = Int16ub.parse(packet)
        packet = packet[2:]
        value = tags[tag].parse(packet)
        packet = packet[tags[tag].sizeof():]
        values.append((tag, value, t))
        if len(packet) == 0:
            break
            
values_keys = {v[0] for v in values}
values = {k: [(v[2], v[1]) for v in values if v[0] == k] for k in values_keys}

# %%
for k in sorted(values_keys):
    vals = values[k]
    plt.figure()
    plt.title(f'Key {k}')
    plt.plot([v[0] for v in vals], [v[1] for v in vals], '.')
# Out:
# <ipython-input-33-6d3e25884fd7>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
