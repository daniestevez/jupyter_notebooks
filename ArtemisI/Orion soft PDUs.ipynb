# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import collections

plt.rcParams['figure.figsize'] = (7, 3.5)
plt.rcParams['figure.facecolor'] = 'w'

# %%
def analysis(path):
    plt.title('Symbol Histogram')
    x = np.fromfile(path, 'float32').reshape(-1, 2048)
    frames = np.packbits((x >= 0).astype('uint8'), axis=1)
    
    plt.hist(x.ravel()[:1000000], bins=300)
    
    plt.figure(figsize=(7, 7))
    plt.imshow(frames, interpolation='none', aspect='auto', vmin=0)

# %%
analysis('orion_2022_11_30_19_17_04_soft_pdus.f32')

# %%
analysis('orion_2022_11_30_18_13_11_soft_pdus.f32')

# %%
analysis('orion_2022_11_30_19_39_43_soft_pdus.f32')

# %%
analysis('orion_2022_11_17_08_56_06_soft_pdus.f32')
